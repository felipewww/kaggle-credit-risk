# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
base_credit = pd.read_csv('./credit_risk_dataset.csv')

# %%
base_credit.isnull().sum()
#person_emp_length / loan_int_rate
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_status                   0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %%
base_credit.loc[pd.isnull(base_credit['loan_int_rate'])]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 39             23          71500                  RENT                3.0
# 50             24          78000                  RENT                4.0
# 57             23         277000                   OWN                3.0
# 59             24          12000                   OWN                2.0
# 62             26         263000              MORTGAGE                0.0
# ...           ...            ...                   ...                ...
# 32547          53           4888                   OWN                0.0
# 32552          65          45900                  RENT                2.0
# 32553          54          20000                  RENT                2.0
# 32569          51          60000              MORTGAGE                1.0
# 32570          58          72000                  RENT                5.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
# fillna preenche todos os campos nulos, o que pode gerar um erro se tiver mais de 1. Tem que tratar 1 por 1
#base_credit.fillna(base_credit['loan_int_rate'].mean(), inplace=True)
base_credit.loc[pd.isnull(base_credit['loan_int_rate']), 'loan_int_rate'] = base_credit['loan_int_rate'].mean()
base_credit.loc[pd.isnull(base_credit['person_emp_length']), 'person_emp_length'] = base_credit['person_emp_length'].mean()

# %%
#base_credit[base_credit[].isin([39,50,57,59,32570,32569])]
# procurar pelos indices para confirmar que foi alterado
base_credit.iloc[[39,50,57,59,32570,32569]]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 39             23          71500                  RENT                3.0
# 50             24          78000                  RENT                4.0
# 57             23         277000                   OWN                3.0
# 59             24          12000                   OWN                2.0
# 32570          58          72000                  RENT                5.0
# 32569          51          60000              MORTGAGE                1.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 39     DEBTCONSOLIDATION          D      30000      11.011695            1
# 50     DEBTCONSOLIDATION          D      30000      11.011695            1
# 57              PERSONAL          A      35000      11.011695            0
# 59               VENTURE          E       1750      11.011695            0
# ...

# %%
base_credit
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...
